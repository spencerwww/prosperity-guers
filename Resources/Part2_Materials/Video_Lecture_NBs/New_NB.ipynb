# %%
import FinancialInstrument as FI

# %%
stock = FI.FinancialInstrument("AAPL", "2015-01-01", "2018-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stock
# Out:
# FinancialInstrument(ticker = AAPL, start = 2015-01-01, end = 2018-01-01)

# %%
stock.data
# Out:
#                 price  log_returns
# Date
# 2015-01-02  24.214895          NaN
# 2015-01-05  23.532719    -0.028576
# 2015-01-06  23.534941     0.000094
# 2015-01-07  23.864944     0.013924
# 2015-01-08  24.781895     0.037703
# ...               ...          ...
# 2017-12-22  40.947598     0.000000
# 2017-12-26  39.908772    -0.025697
# 2017-12-27  39.915783     0.000176
# 2017-12-28  40.028099     0.002810
# 2017-12-29  39.595238    -0.010873
#
# [755 rows x 2 columns]
