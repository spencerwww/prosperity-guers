# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from itertools import product
plt.style.use("seaborn-v0_8")

# %%
prices_raw_1 = pd.read_csv("prices_round_4_day_1.csv", sep = ";", index_col = "timestamp")

# %%
hgp = prices_raw_1[prices_raw_1["product"] == "HYDROGEL_PACK"]
hgp
# Out:
#            day        product  bid_price_1  bid_volume_1  bid_price_2  \
# timestamp
# 0            1  HYDROGEL_PACK         9950            13       9947.0
# 100          1  HYDROGEL_PACK         9953            15       9950.0
# 200          1  HYDROGEL_PACK         9953            14       9951.0
# 300          1  HYDROGEL_PACK         9952            15       9950.0
# 400          1  HYDROGEL_PACK         9953            10       9951.0
# ...        ...            ...          ...           ...          ...
# 999500       1  HYDROGEL_PACK        10011            10      10009.0
# 999600       1  HYDROGEL_PACK        10011            15      10008.0
# 999700       1  HYDROGEL_PACK        10009            11      10007.0
# 999800       1  HYDROGEL_PACK        10005            15      10003.0
# 999900       1  HYDROGEL_PACK        10007            15      10004.0
#
#            bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# timestamp
# ...

# %%
hgp = hgp.copy()
hgp["mid_price"].plot()
# Out:
# <Axes: xlabel='timestamp'>

# %%
trades_raw_1 = pd.read_csv("trades_round_4_day_1.csv", sep = ";", index_col = "timestamp")

# %%
hgp_trades = trades_raw_1[trades_raw_1["symbol"] == "HYDROGEL_PACK"]
hgp_trades = hgp_trades.reindex(hgp.index)

hgp_trades
# Out:
# <Axes: xlabel='timestamp'>
