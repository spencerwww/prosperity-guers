# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from itertools import product
plt.style.use("seaborn-v0_8")

# %%
prices_raw_neg_2 = pd.read_csv("prices_round_1_day_-2.csv", sep = ";", index_col = "timestamp")
prices_raw_neg_1 = pd.read_csv("prices_round_1_day_-1.csv", sep = ";", index_col = "timestamp")
prices_raw_0 = pd.read_csv("prices_round_1_day_0.csv", sep = ";", index_col = "timestamp")

# %%
prices_raw_neg_1.index = prices_raw_neg_1.index + prices_raw_neg_2.index.max() + 100
prices_raw_neg_1
# Out:
#            day               product  bid_price_1  bid_volume_1  bid_price_2  \
# timestamp
# 1000000     -1  INTARIAN_PEPPER_ROOT      10991.0          15.0          NaN
# 1000000     -1     ASH_COATED_OSMIUM          NaN           NaN          NaN
# 1000100     -1     ASH_COATED_OSMIUM       9984.0          11.0          NaN
# 1000100     -1  INTARIAN_PEPPER_ROOT      10994.0           9.0      10991.0
# 1000200     -1     ASH_COATED_OSMIUM       9985.0          15.0       9982.0
# ...        ...                   ...          ...           ...          ...
# 1999700     -1  INTARIAN_PEPPER_ROOT      11993.0          10.0          NaN
# 1999800     -1  INTARIAN_PEPPER_ROOT      11993.0          12.0      11990.0
# 1999800     -1     ASH_COATED_OSMIUM       9994.0          13.0       9992.0
# 1999900     -1     ASH_COATED_OSMIUM       9994.0          10.0          NaN
# 1999900     -1  INTARIAN_PEPPER_ROOT      11990.0          25.0          NaN
#
# ...

# %%
prices_raw_0.index = prices_raw_0.index + prices_raw_neg_1.index.max() + 100
prices_raw_0
# Out:
#            day               product  bid_price_1  bid_volume_1  bid_price_2  \
# timestamp
# 2000000      0     ASH_COATED_OSMIUM          NaN           NaN          NaN
# 2000000      0  INTARIAN_PEPPER_ROOT      11991.0          19.0          NaN
# 2000100      0  INTARIAN_PEPPER_ROOT      11994.0           9.0      11991.0
# 2000100      0     ASH_COATED_OSMIUM       9995.0          13.0          NaN
# 2000200      0  INTARIAN_PEPPER_ROOT      11991.0          20.0          NaN
# ...        ...                   ...          ...           ...          ...
# 2999700      0  INTARIAN_PEPPER_ROOT      12989.0          20.0          NaN
# 2999800      0  INTARIAN_PEPPER_ROOT          NaN           NaN          NaN
# 2999800      0     ASH_COATED_OSMIUM          NaN           NaN          NaN
# 2999900      0     ASH_COATED_OSMIUM       9998.0          21.0          NaN
# 2999900      0  INTARIAN_PEPPER_ROOT      12990.0          23.0          NaN
#
# ...

# %%
prices_raw = pd.concat([prices_raw_neg_2, prices_raw_neg_1, prices_raw_0], axis=0)
prices_raw
# Out:
#            day               product  bid_price_1  bid_volume_1  bid_price_2  \
# timestamp
# 0           -2  INTARIAN_PEPPER_ROOT       9992.0          17.0          NaN
# 0           -2     ASH_COATED_OSMIUM          NaN           NaN          NaN
# 100         -2  INTARIAN_PEPPER_ROOT       9995.0          11.0       9992.0
# 100         -2     ASH_COATED_OSMIUM       9992.0          15.0          NaN
# 200         -2  INTARIAN_PEPPER_ROOT       9995.0          12.0          NaN
# ...        ...                   ...          ...           ...          ...
# 2999700      0  INTARIAN_PEPPER_ROOT      12989.0          20.0          NaN
# 2999800      0  INTARIAN_PEPPER_ROOT          NaN           NaN          NaN
# 2999800      0     ASH_COATED_OSMIUM          NaN           NaN          NaN
# 2999900      0     ASH_COATED_OSMIUM       9998.0          21.0          NaN
# 2999900      0  INTARIAN_PEPPER_ROOT      12990.0          23.0          NaN
#
# ...

# %%
aco = prices_raw[prices_raw["product"] != "INTARIAN_PEPPER_ROOT"]
aco
# Out:
#            day            product  bid_price_1  bid_volume_1  bid_price_2  \
# timestamp
# 0           -2  ASH_COATED_OSMIUM          NaN           NaN          NaN
# 100         -2  ASH_COATED_OSMIUM       9992.0          15.0          NaN
# 200         -2  ASH_COATED_OSMIUM       9992.0          15.0       9989.0
# 300         -2  ASH_COATED_OSMIUM       9992.0          13.0       9989.0
# 400         -2  ASH_COATED_OSMIUM       9992.0          15.0          NaN
# ...        ...                ...          ...           ...          ...
# 2999500      0  ASH_COATED_OSMIUM      10000.0          13.0       9997.0
# 2999600      0  ASH_COATED_OSMIUM      10000.0          14.0       9997.0
# 2999700      0  ASH_COATED_OSMIUM      10000.0          11.0       9997.0
# 2999800      0  ASH_COATED_OSMIUM          NaN           NaN          NaN
# 2999900      0  ASH_COATED_OSMIUM       9998.0          21.0          NaN
#
# ...

# %%
aco = aco.copy()
aco["mid_price"] = aco["mid_price"].replace(0, np.nan).ffill()

# %%
print(aco.ask_price_1.mean())
print(aco.mid_price.mean())
print(aco.bid_price_1.mean())
# Out:
# 10008.289350324663
# 10000.20605
# 9992.122968467842

# %%
start = 10000
window = 3000
range = [start, start + window]

aco[["mid_price"]].plot(figsize = (15, 8), fontsize = 13, xlim=(range[0], range[1]))
plt.legend(fontsize = 13)
plt.show()
